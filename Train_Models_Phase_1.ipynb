# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.utils.testing import all_estimators

# %%
X_train = pd.read_csv('X_train.csv', index_col=0)
y_train = pd.read_csv('y_train.csv', index_col=0, names=(['Label']))

# %%
X_train.head()
# Out:
#       Jan  Aug  Sept  Oct  Nov  Dec  Team1Site  Team2Site  \
# 4288    0    0     1    0    0    0          1         -1
# 5732    0    0     0    0    1    0          1         -1
# 2419    0    0     0    0    0    1          0          0
# 5231    0    0     1    0    0    0          1         -1
# 2019    0    0     0    1    0    0          1         -1
#
#       Team1_Win_Precentage   ML1      ...       Team2_MAC  Team2_MWC  \
# 4288              0.333333   460      ...               0          0
# 5732              0.538462   100      ...               1          0
# 2419              0.500000   465      ...               0          0
# 5231              0.538462 -7000      ...               0          0
# 2019              0.857143 -5190      ...               0          0
#
#       Team2_Pac-10  Team2_Pac-12  Team2_SEC  Team2_SunBelt  Team2_WAC  \
# 4288             0             0          0              0          0
# ...

# %%
y_train.head()
# Out:
#       Label
# 4288      1
# 5732      0
# 2419      1
# 5231      1
# 2019      1

# %%
cols = list(X_train)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train, columns=cols)
X_train.head()
# Out:
#         Jan       Aug      Sept       Oct       Nov       Dec  Team1Site  \
# 0 -0.118451 -0.117354  1.656182 -0.699914 -0.681636 -0.251234   0.250100
# 1 -0.118451 -0.117354 -0.603798 -0.699914  1.467058 -0.251234   0.250100
# 2 -0.118451 -0.117354 -0.603798 -0.699914 -0.681636  3.980354  -3.998397
# 3 -0.118451 -0.117354  1.656182 -0.699914 -0.681636 -0.251234   0.250100
# 4 -0.118451 -0.117354 -0.603798  1.428746 -0.681636 -0.251234   0.250100
#
#    Team2Site  Team1_Win_Precentage       ML1      ...       Team2_MAC  \
# 0  -0.250100             -0.909936  0.182659      ...       -0.315089
# 1  -0.250100              0.009581  0.148548      ...        3.173708
# 2   3.998397             -0.162829  0.183133      ...       -0.315089
# 3  -0.250100              0.009581 -0.524200      ...       -0.315089
# 4  -0.250100              1.438117 -0.352697      ...       -0.315089
#
#    Team2_MWC  Team2_Pac-10  Team2_Pac-12  Team2_SEC  Team2_SunBelt  Team2_WAC  \
# ...

# %%
classifiers = all_estimators(type_filter = 'classifier')
#print(classifiers)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# ...

# %%
classifier_num = range(len(classifiers))
imports = []
froms = []
as_label = []
import_names = []
for name,num in zip(classifiers,classifier_num):
    classifier = str(classifiers[num][1])
    classifier = classifier.replace("<class '","").replace("'>","")
    classifier = classifier.rsplit('.', 1)
    froms.append(classifier[0])
    imports.append(classifier[1])
    as_label.append([char for char in classifier[1] if char.isupper()])  
    code = "from {} import {}".format(classifier[0],classifier[1])
    exec(code)
    print("Code ran: {}".format(code))
    
for name in as_label:
    name = ''.join(name)
    if name in import_names:
        import_names.append(''.join(name+"1"))
    else:
        import_names.append(''.join(name))
# Out:
# Code ran: from sklearn.ensemble.weight_boosting import AdaBoostClassifier
# Code ran: from sklearn.ensemble.bagging import BaggingClassifier
# Code ran: from sklearn.naive_bayes import BernoulliNB
# Code ran: from sklearn.calibration import CalibratedClassifierCV
# Code ran: from sklearn.tree.tree import DecisionTreeClassifier
# Code ran: from sklearn.tree.tree import ExtraTreeClassifier
# Code ran: from sklearn.ensemble.forest import ExtraTreesClassifier
# Code ran: from sklearn.naive_bayes import GaussianNB
# Code ran: from sklearn.gaussian_process.gpc import GaussianProcessClassifier
# Code ran: from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
# Code ran: from sklearn.neighbors.classification import KNeighborsClassifier
# Code ran: from sklearn.semi_supervised.label_propagation import LabelPropagation
# Code ran: from sklearn.semi_supervised.label_propagation import LabelSpreading
# ...

# %%
for var,module in zip(import_names,imports):
    init_var = "{} = {}()".format(var,module)
    exec(init_var)
    print(init_var)
# Out:
# ABC = AdaBoostClassifier()
# BC = BaggingClassifier()
# BNB = BernoulliNB()
# CCCV = CalibratedClassifierCV()
# DTC = DecisionTreeClassifier()
# ETC = ExtraTreeClassifier()
# ETC1 = ExtraTreesClassifier()
# GNB = GaussianNB()
# GPC = GaussianProcessClassifier()
# GBC = GradientBoostingClassifier()
# KNC = KNeighborsClassifier()
# LP = LabelPropagation()
# LS = LabelSpreading()
# LDA = LinearDiscriminantAnalysis()
# LSVC = LinearSVC()
# LR = LogisticRegression()
# LRCV = LogisticRegressionCV()
# MLPC = MLPClassifier()
# MNB = MultinomialNB()
# NC = NearestCentroid()
# NSVC = NuSVC()
# PAC = PassiveAggressiveClassifier()
# P = Perceptron()
# QDA = QuadraticDiscriminantAnalysis()
# RNC = RadiusNeighborsClassifier()
# RFC = RandomForestClassifier()
# RC = RidgeClassifier()
# RCCV = RidgeClassifierCV()
# SGDC = SGDClassifier()
# SVC = SVC()

# %%
ABC
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
for model in import_names:
    clf = model.fit(X_train,y_train)
    y_pred =

# %%
#KNNC.fit(X_train, y_train)
#y_train_pred = KNNC.predict(X_train)
#y_train_proba = KNNC.predict_proba(X_train)
#accuracy_score(y_train,y_train_pred)
