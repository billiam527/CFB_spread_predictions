# %%
import pandas as pd
import numpy as np

# %%
years = list(range(10,18))

for i in years:
    for j in list(range(0,8)):
        df+j = i
# Out:
#   File "<ipython-input-9-89abefab5cf0>", line 5
#     df+j = i
#     ^
# SyntaxError: can't assign to operator

# %%
list(range(0,8))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
csv = {}
for i in range(10,18):
    file = 'School_20{}_stats.csv'.format(i) 
    csv[file] = pd.read_csv(file)

# %%
csv
# Out:
# {'School_2010_stats.csv':      Unnamed: 0                  School            Conf  AP Rank   W   L  \
#  0             0                Stanford          Pac-10      4.0  12   1
#  1             1                  Oregon          Pac-10      3.0  12   1
#  2             2                  Auburn      SEC (West)      1.0  14   0
#  3             3             Boise State             WAC      9.0  12   1
#  4             4                 Alabama      SEC (West)     10.0  10   3
#  5             5         Texas Christian             MWC      2.0  13   0
#  6             6              Ohio State         Big Ten      5.0  12   1
#  7             7                Oklahoma  Big 12 (South)      6.0  12   2
#  8             8          Oklahoma State  Big 12 (South)     13.0  11   2
#  9             9                     LSU      SEC (West)      8.0  11   2
#  10           10                Arkansas      SEC (West)     12.0  10   3
# ...
