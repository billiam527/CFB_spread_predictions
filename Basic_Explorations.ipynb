# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("combined_edited_spreads_and_ratings_df.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       Date  Month Team1Site Team2Site          Team1  \
# 0           0  9/02/2010      9         H         V  SouthCarolina
# 1           1  9/02/2010      9         H         V      OhioState
# 2           2  9/02/2010      9         H         V      IowaState
# 3           3  9/02/2010      9         H         V           Utah
# 4           4  9/02/2010      9         H         V         Hawaii
#
#    Team1_Win_Precentage  Final1  Open1  Close1     ...      Team2_TotalOff  \
# 0              0.642857      41   13.5    13.0     ...                5.08
# 1              0.923077      45   28.5    28.0     ...                4.48
# 2              0.416667      27    3.0     4.0     ...                6.08
# 3              0.769231      27    3.5     3.5     ...                5.67
# 4              0.714286      36   53.5    51.0     ...                6.07
#
#   Team2_TotalDef  Team1_Win  Total_Open  Total_Close  Spread_Open  \
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.describe()
# Out:
#              Month  Team1_Win_Precentage       Final1        Open1  \
# count  5679.000000           5679.000000  5679.000000  5679.000000
# mean     10.011798              0.535529    30.232787    28.108822
# std       1.422174              0.223195    14.308668    22.573434
# min       1.000000              0.000000     0.000000     0.500000
# 25%       9.000000              0.333333    20.000000     8.000000
# 50%      10.000000              0.538462    30.000000    18.500000
# 75%      11.000000              0.692308    41.000000    51.500000
# max      12.000000              1.000000    83.000000    87.000000
#
#             Close1            ML1  Team1_AP_Rank      Team1_W      Team1_L  \
# count  5679.000000    5679.000000    5679.000000  5679.000000  5679.000000
# mean     28.579944   -1304.158831      54.525092     6.955274     5.817574
# std      22.599497    9232.466382      23.075294     3.125942     2.602631
# ...

# %%
df.shape
# Out:
# (5679, 54)

# %%
list(df)
# Out:
# ['Date',
#  'Month',
#  'Team1Site',
#  'Team2Site',
#  'Team1',
#  'Team1_Win_Precentage',
#  'Final1',
#  'Open1',
#  'Close1',
#  'ML1',
#  'Team1_Conf',
#  'Team1_AP_Rank',
#  'Team1_W',
#  'Team1_L',
#  'Team1_OSRS',
#  'Team1_DSRS',
#  'Team1_SRS',
#  'Team1_ScoringOff',
#  'Team1_ScoringDef',
#  'Team1_PassingOff',
#  'Team1_PassingDef',
#  'Team1_RushingOff',
#  'Team1_RushingDef',
#  'Team1_TotalOff',
#  'Team1_TotalDef',
#  'Team2',
#  'Team2_Win_Precentage',
#  'Final2',
#  'Open2',
#  'Close2',
#  'ML2',
#  'Team2_Conf',
#  'Team2_AP_Rank',
#  'Team2_W',
#  'Team2_L',
#  'Team2_OSRS',
#  'Team2_DSRS',
#  'Team2_SRS',
#  'Team2_ScoringOff',
#  'Team2_ScoringDef',
#  'Team2_PassingOff',
#  'Team2_PassingDef',
#  'Team2_RushingOff',
#  'Team2_RushingDef',
#  'Team2_TotalOff',
#  'Team2_TotalDef',
#  'Team1_Win',
#  'Total_Open',
#  'Total_Close',
#  'Spread_Open',
#  'Spread_Close',
#  'Team1_Point_Dif',
#  'Team1Cover',
#  'Over_Under']

# %%
df['Team1Cover'].value_counts()
# Out:
# 0    2948
# 1    2731
# Name: Team1Cover, dtype: int64

# %%
df['Team1Cover'].value_counts(normalize=True)
# Out:
# 0    0.519105
# 1    0.480895
# Name: Team1Cover, dtype: float64

# %%
df[df['Team1Cover'] == 1].median()
# Out:
# Month                    10.000000
# Team1_Win_Precentage      0.615385
# Final1                   37.000000
# Open1                    18.500000
# Close1                   20.000000
# ML1                    -200.000000
# Team1_AP_Rank            67.000000
# Team1_W                   8.000000
# Team1_L                   5.000000
# Team1_OSRS                1.940000
# Team1_DSRS                1.470000
# Team1_SRS                 3.640000
# Team1_ScoringOff         43.030000
# Team1_ScoringDef         14.530000
# Team1_PassingOff          8.510000
# Team1_PassingDef          5.930000
# Team1_RushingOff          4.870000
# Team1_RushingDef          3.830000
# Team1_TotalOff            6.620000
# Team1_TotalDef            4.740000
# Team2_Win_Precentage      0.500000
# Final2                   18.000000
# Open2                    50.000000
# Close2                   49.500000
# ML2                     170.000000
# Team2_AP_Rank            67.000000
# Team2_W                   6.000000
# ...

# %%
df[df['Team1Cover'] == 0].median()
# Out:
# Month                    10.000000
# Team1_Win_Precentage      0.538462
# Final1                   23.000000
# Open1                    18.500000
# Close1                   20.000000
# ML1                    -190.000000
# Team1_AP_Rank            67.000000
# Team1_W                   7.000000
# Team1_L                   6.000000
# Team1_OSRS                0.340000
# Team1_DSRS               -0.205000
# Team1_SRS                 1.180000
# Team1_ScoringOff         42.140000
# Team1_ScoringDef         14.810000
# Team1_PassingOff          8.310000
# Team1_PassingDef          5.930000
# Team1_RushingOff          4.860000
# Team1_RushingDef          3.790000
# Team1_TotalOff            6.465000
# Team1_TotalDef            4.745000
# Team2_Win_Precentage      0.571429
# Final2                   31.000000
# Open2                    49.500000
# Close2                   49.000000
# ML2                     165.000000
# Team2_AP_Rank            67.000000
# Team2_W                   7.000000
# ...

# %%
pd.crosstab(df['Team1Cover'], df['Team1Site'])
# Out:
# Team1Site      H    N
# Team1Cover
# 0           2792  156
# 1           2558  173

# %%
df['Favorite'] = np.where(pd.to_numeric(df['ML1']) < 0, 1, 0)

# %%
pd.crosstab(df['Team1Cover'], df['Favorite'])
# Out:
# Favorite       0     1
# Team1Cover
# 0           1090  1858
# 1            982  1749

# %%
df.corr(df['Team1Cover'])
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py:1167: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fcfec60645bc> in <module>()
# ----> 1 df.corr(df['Team1Cover'])
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods)
#    6504         mat = numeric_df.values
#    6505
# -> 6506         if method == 'pearson':
#    6507             correl = libalgos.nancorr(_ensure_float64(mat), minp=min_periods)
#    6508         elif method == 'spearman':
#
# ...
